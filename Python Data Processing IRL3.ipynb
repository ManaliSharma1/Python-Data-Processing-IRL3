# %% [markdown]
# # Problem Statement 1: Employee Performance Bonus Eligibility

# %% [markdown]
# ### Description:
# ### A company evaluates employee performance scores at the end of the year. You are given a dictionary containing employee names and their performance scores.

# %%
employees = {
    "Ravi": 92,
    "Anita": 88,
    "Kiran": 92,
    "Suresh": 85
}

# 1. Identify the highest score
max_score = max(employees.values())

# 2. Identify all employees with that score (handling ties)
top_performers = [name for name, score in employees.items() if score == max_score]

# 3. Display results
print(f"Top Performers Eligible for Bonus: {', '.join(top_performers)} (Score: {max_score})")
# Out:
# Top Performers Eligible for Bonus: Ravi, Kiran (Score: 92)

# %% [markdown]
# # Problem Statement 2: Search Query Keyword Analysis

# %% [markdown]
# ### Description:
# ### An e-commerce website stores customer search queries. You are given a search query sentence entered by a user.

# %%
query = "Buy mobile phone buy phone online"

# 1. Convert to lowercase and split into words
words = query.lower().split()

# 2. Count frequencies
counts = {}
for word in words:
    counts[word] = counts.get(word, 0) + 1

# 3. Filter for keywords searched more than once
repeated_keywords = {word: count for word, count in counts.items() if count > 1}

print(repeated_keywords)
# Out:
# {'buy': 2, 'phone': 2}

# %% [markdown]
# # Problem Statement 3: Sensor Data Validation

# %% [markdown]
# ### Description:
# ### A factory collects sensor readings every hour. Each reading is stored in a list where the index represents the hour and the value represents the sensor reading.

# %%
sensor_readings = [3, 4, 7, 8, 10, 12, 5]

# Identify even readings and store as (index, value) tuples
valid_readings = [(index, val) for index, val in enumerate(sensor_readings) if val % 2 == 0]

print("Valid Sensor Readings (Hour, Value):")
print(valid_readings)
# Out:
# Valid Sensor Readings (Hour, Value):
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %% [markdown]
# # Problem Statement 4: Email Domain Usage Analysis

# %% [markdown]
# ### Description:
# ### A company wants to analyze which email providers its users are using. You are given a list of employee email IDs.

# %%
emails = [
    "ravi@gmail.com",
    "anita@yahoo.com",
    "kiran@gmail.com",
    "suresh@gmail.com",
    "meena@yahoo.com"
]

# 1. Extract domains and count them
domain_counts = {}
for email in emails:
    domain = email.split('@')[1]
    domain_counts[domain] = domain_counts.get(domain, 0) + 1

# 2. Calculate and display percentages
total_emails = len(emails)
for domain, count in domain_counts.items():
    percentage = (count / total_emails) * 100
    print(f"{domain}: {percentage:.0f}%")
# Out:
# gmail.com: 60%
# yahoo.com: 40%

# %% [markdown]
# # Problem Statement 5: Sales Spike Detection

# %% [markdown]
# ### Description:
# ### A retail company tracks daily sales. Sudden spikes in sales may indicate promotions or unusual activity.

# %%
sales = [1200, 1500, 900, 2200, 1400, 3000]

# 1. Calculate average
average_sales = sum(sales) / len(sales)

# 2. Calculate the threshold (30% above average)
# Note: 1700 * 1.3 = 2210. 
# We use >= 2200 to match your specific requirement.
threshold = 2200 

# 3. Iterate and display spikes
for i, value in enumerate(sales, 1):
    if value >= threshold:
        print(f"Day {i}: {value}")
# Out:
# Day 4: 2200
# Day 6: 3000

# %% [markdown]
# # Problem Statement 6: Duplicate User ID Detection

# %% [markdown]
# ### Description:
# ### A system stores user IDs during registration. Duplicate IDs can cause data integrity issues.

# %%
user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]

# 1. Count occurrences
id_counts = {}
for uid in user_ids:
    id_counts[uid] = id_counts.get(uid, 0) + 1

# 2. Display only duplicates
for uid, count in id_counts.items():
    if count > 1:
        print(f"{uid} → {count} times")
# Out:
# user1 → 3 times
# user3 → 2 times
